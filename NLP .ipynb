# %%
#importar librerias 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importar data set
data=pd.read_excel('SA.xlsx')

# %%
data = data[['text','sentiment']]

# %%
##Limpieza de texto
import re 
def clean_text (df, text_field): 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'https://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', ' ', elem ))   
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'publici(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'publicidad', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@wom(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'wom', elem ))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'wom(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'wom', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@entel(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+' , 'entel', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@movistar(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'movistar', elem))
    df [text_field] = df [text_field].str.lower() 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:á)', 'a', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:é)', 'e', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:í)', 'i', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ó)', 'o', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ú)', 'u', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ll)', 'yxy', elem))#guardar las ll 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:rr)', 'yxr', elem))#guardar las rr 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(.)\1+', r'\1', elem))#saca letras repetidas
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:yxy)', 'll', elem))#devuelve  la ll
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:yxr)', 'rr', elem))#devuelve  la rr
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:bkn)', 'buena', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:rt )', ' ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?: q )', ' que ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?: k )', ' que ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:guena)', ' buena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:wena)', ' buena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:\\n)', ' ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'jajaja(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'jajaja', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'ajaja(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'jajaja', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😂,🤣,😅])', ' jajaja ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😁,😎,😊,😘,🙈,🤭,😋,😄,😆])', ' bien ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😡,😠,😒,🤬])', ' enojo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😭,😢,😪,😞,😔,😫,😌,😩])', ' pena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[🍄,🤦,🤦,🤦🏼,🤦,😤,😕,💩,😖,🤮,🐌,🖕,😑,💔,👎🏻])', 'pesimo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[❤️,💓,💕,💜,😍])', ' encanta ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[👏])', ' bravo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:@[\w_]+)', ' ', elem)) #quita las menciones 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'[^\w\ \s]','', elem)) #quita los emoticones (Deja solo letras y espacios)
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'\b(\w+)( \1\b)+', r'\1', elem))#elimina repetidos
    return df 
data=clean_text(data,'text')
#quitar neutros 
dataset = data[data.sentiment != 'Neutro']
dataset
# Out:
#                                                    text sentiment
# 0     dia de celebracion encanta muchas gracias a wo...    Bueno
# 1     dia de celebracion encanta muchas gracias a wo...    Bueno
# 2      entel si jajaja luego te cobran lo que quiere...    Bueno
# 3     jajaja aguante wom me porte hace mas de un año...    Bueno
# 4     wom funciona perfecto en su red 4gpero cuando ...    Bueno
# 5      entel aguante wom no te cortan nunca el servi...    Bueno
# 6      cambiense a wom atencion inmediata y cordial ...    Bueno
# 7      entel portate a wom yo era movistar y me port...    Bueno
# 8      hagame caso y cambiese a wom como yo jajaja q...    Bueno
# 9      entel le dije que hiciera eso jajaja es el ce...    Bueno
# 10    esos dias donde te das cuenta que hacer migrad...    Bueno
# 11    oye wom buena la copia de la escena a mentiras...    Bueno
# 12        lo mantengo jajaja migrar a wom fue lo mejor     Bueno
# 13    fui por 16 años clienta de y hoy soy wom y fel...    Bueno
# 14     entel compadre jajaja no pierda mas plata ni ...    Bueno
# 15     entel compadre jajaja no pierda mas plata ni ...    Bueno
# 16     entel gracias wom por regalarme un chip para ...    Bueno
# 17     entel se fue a la xuxa jajaja dejo de ser la ...    Bueno
# 18     cambiate a wom nunca he tenido ningun problem...    Bueno
# 19     wom llevo ya m 2 años o un poco mas con chile...    Bueno
# 20     wom buena jajaja si la decision esta tomada e...    Bueno
# 21            wom siempre wom jajaja nunca inwom jajaja    Bueno
# 22     corazon jajaja yo me cambie a wom y terminaro...    Bueno
# 23    apostaria a que wom lo pesca para algun comerc...    Bueno
# 24    para ser justa me soluciono mi problema con wo...    Bueno
# 25     wom yo ya llevo dos años y ningun problema en...    Bueno
# 26     aplica wom dentro de todos los males jajaja e...    Bueno
# 27    y pensar que antes pagabamos arriba de 30 por ...    Bueno
# 28    wom querido amigo wom siempre llevas la delant...    Bueno
# 29    hey ya esta bueno jajaja corten con su acoso i...    Bueno
# ...                                                 ...       ...
# 1068  no espero nada de wom y aun asi logra decepcio...      Malo
# 1069  q pesima la señal de wom ahora si que pensando...      Malo
# 1070   wom no tiene 4g ni lte jajaja es lo unico mal...      Malo
# 1071   wom lo siento no ay mejoras en atencion al cl...      Malo
# 1072   wom hice lo mismo y me arrepiento jajaja el 4...      Malo
# 1073  wom tuve un fuerte problema en sucursal del ce...      Malo
# 1074  wom necesito una respuesta ahora por lo sucedi...      Malo
# 1075  pesimos servicio wom super decepcionada del di...      Malo
# 1076  wom pedi la baja de mis 3 lineas y me llegan e...      Malo
# 1077  bueno ya que wom se hizo el wom jajaja tuve qu...      Malo
# 1078  sigo con mala señal jajaja no contesta el ejec...      Malo
# 1079                                   es muy penca wom      Malo
# 1080   wom yo soy usuario wom pero la señal al dia d...      Malo
# 1081  termino el eclipse en la serena y wom anda com...      Malo
# 1082   una mierda el tio wom el equipo sale malo y n...      Malo
# 1083  decepcionado de comprar telefono en wom ya que...      Malo
# 1084   bueno ya que wom se hizo el wom jajaja tuve q...      Malo
# 1085  wom llame al 105 hace 1 dias por este problema...      Malo
# 1086    que pasa con el 4g en antofagasta wom lentisimo      Malo
# 1087    que pasa con el 4g en antofagasta wom lentisimo      Malo
# 1088  wom porque me tienen una deuda sobre 20 ha si ...      Malo
# 1089  wom hace 17 dias me encuentro sin servicio de ...      Malo
# 1090  wom que pasa con los datos aca en talcahuano p...      Malo
# 1091  wom srs no sean tan frescos me llaman cobrando...      Malo
# 1092  tio wom todos los dias quedo sin servicio unas...      Malo
# 1093   wom navegacion lenta para variar a esta hora ...      Malo
# 1094   se deja en evidencia que y wom son unos incom...      Malo
# 1095  quiero manifestar una queja publica con el ser...      Malo
# 1096  wom estoy desde las 170 hrs sin servicio en mi...      Malo
# 1097   muy mal jajaja el cliente es lo primero eso t...      Malo
#
# [1098 rows x 2 columns]

# %%
import nltk #toolkit
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud,STOPWORDS
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("spanish")
#quitar stop word y realizar steming
corpus=[]
for i in range(0,1098):
    text=dataset['text'][i]
    text=text.split()
    text=[stemmer.stem(word) for word in text if not word in set(stopwords.words('spanish'))]
    text=' '.join(text)
    corpus.append(text)

# %%
corpus
# Out:
# ['dia celebracion encant much graci wom gran regalit insideteaconectioncl ric desayun campeon tremend oportun mentor lalemez',
#  'dia celebracion encant much graci wom gran regalit insideteaconectioncl ric desayun campeon tremend oportun mentor lalemez',
#  'entel si jajaj lueg cobr quier cambi wom nl mas dram inclus mas gig mism plat',
#  'jajaj aguant wom port hac mas año nunc cobr adicional letr chic buen trabaj felicit empres piens client',
#  'wom funcion perfect red 4gper pas roaming mism jajaj 0 navegacion linea5',
#  'entel aguant wom cort nunc servici jajaj siempr pag atras jaj tio wom',
#  'cambiens wom atencion inmediat cordial jajaj solucion rap dram jajaj hart mas barat mejor plan pas x tod compañi wom mejorcit entel jajaj movist peor',
#  'entel portat wom movist port wom jajaj excelent servici',
#  'hagam cas camb wom jajaj aburr maltrat pes ser client mas 20 años jajaj cans facil jajaj rap barat',
#  'entel dij hic jajaj celul pap suert wom mism celu jajaj si estari incomunic total',
#  'dias das cuent hac migr wom mejor d',
#  'oye wom buen copi escen mentir verdader schwarzeneg',
#  'manteng jajaj migr wom mejor',
#  '16 años client hoy wom feliz veo reclam entel nul servici won xd wom',
#  'entel compadr jajaj pierd mas plat tiemp rabi wnes carer vayal wom mit plat anda parejit b',
#  'entel compadr jajaj pierd mas plat tiemp rabi wnes carer vayal wom',
#  'entel graci wom regal chip cel mientr solucion problem vendermel queri hac entel',
#  'entel xux jajaj dej ser top jajaj wom pase ahor cobertur pic',
#  'cambiat wom nunc ningun problem amabl',
#  'wom llev m 2 años mas chil cer problem viaj funcion perfect aburri regal plat',
#  'wom buen jajaj si decision tom mes ser wom jajaj',
#  'wom siempr wom jajaj nunc inwom jajaj',
#  'corazon jajaj cambi wom termin problem',
#  'apostari wom pesc algun comercial xd',
#  'ser just solucion problem wom carit feliz primer',
#  'wom llev dos años ningun problem encant',
#  'aplic wom dentr mal jajaj men mal jajaj men trat solucion problem mejor plan',
#  'pens pagab arrib 30 plan celul jajaj ahor 1 luk qued perfect pesim graci wom',
#  'wom quer amig wom siempr llev delanter jajaj segu pag roaming yap pongans pil',
#  'hey buen jajaj cort acos insist tio wom llev bien cambiar',
#  'wom const arregl servici ahot net voy pat net ok jajaj',
#  'amig wom usted empres hac mas año excelent servici abrir pront local elec',
#  'hey buen jajaj cort acos insist tio wom llev bien cambiar htp',
#  'pens pagab arrib 30 plan celul jajaj ahor 1 luk qued perfect pesim graci wom',
#  'wom tal wom cuñ dic anda sup bien',
#  'cambi mayor cobertur equivoqu pen curarrehu señal graci amig wom dad internet chalalor',
#  'asquit movist jajaj qued pokit regres wom debi nunc verm ido jam dram',
#  'camb wom cambi vid adem atiend wasap solucion rapid jajaj viv puebl chic sur chil 4g 247 tod seman verd jajaj mejor salud',
#  'notabl form wom redit ultim comercial jajaj famos imag pelicul tru lies espectacul jami curtis incombust arni pesim',
#  'wom muse muse cer jajaj',
#  'wom mil vec mejor compr sim card prepag',
#  'wom jajaj tambi extrañ jajaj pesim',
#  'graci wom internet movil pued trabaj cas rep internet fij mal viern penc movist',
#  'wom funcion bien except ap crunchyroll',
#  'años siend siempr jajaj apen subi metr lugar cerr qued internet jajaj hoy qe cambi wom acab ver vide metr vide mit luc encant',
#  'wom incorrect 50 gb 4g mas 30 gb 3g plan particul jajaj adem si exced cantid baj veloc jajaj nunc cort internet jajaj asi public engañ',
#  'favor borr numer registr podr llamadastod dias jajaj 2 3 vecesp port entel har aun gratis client 15 años jajaj siempr sup cuid ahor feliz wom graci',
#  'wom jajaj muse cer armo polem jajaj',
#  'wom excelent años renuev minut internet ilimit 12 luc mensual señal fall',
#  'wom llev mes wom ningun problem jajaj señal lugar nunc clar jajaj movist entel asi quej moment',
#  'tio wom uni fil pesim mandel salud antigu trop jajaj',
#  'wom encant encant hac weas',
#  'sab product placement bien ahi wom islaparais',
#  'wom lleg islaparais isla nivel jajaj bien jajaj',
#  'wom jajaj notabl',
#  'mejor altern wom mejor empres telefoni movil chil',
#  'wom hic vez brav pesim brav pesim brav pesim lmg',
#  'wom dim brom jajaj',
#  'pesim servici jajaj señal vari part compromis resolv problem tov client adem car servici jajaj terci cobr wom encuentr mejor servici respuest',
#  'cobr arrug apañ wom siempr',
#  'entel sol stoy sper wom perfecion servici jajaj lleg ser mejor compañi',
#  'deberi pag comision jajaj cambi cas wom',
#  'wom lej mejor opcion content mat 20 lit',
#  'entel cambiat wom llev mas 1 año dram si problem solucion inmediat',
#  'wom mejor bastant cerronavi brav',
#  'wom tab wom sorprendi',
#  'wom tab wom sorprendi',
#  'wom jajaj aca anda bien entel wum',
#  'wom graci apoy guachitapesim encant',
#  'wom verd just viv funcion raj jajaj dem santiag maitencill pesim encant',
#  'wom port wom fin seman jajaj hic test mism lug result brav pesim wom makin valdiviacl',
#  'wom buen servici buen promocion',
#  'diri si tir jajaj estari año mas esper destap tuberi uds mism tap asi mejor sig wom hog',
#  'wom sres verd cambi buen servici abus compañi favor mand cuent avis 0130 mañan lleg avis qued peg tech jajaj',
#  'competent gener calid graci jajaj wom via',
#  'wom jajaj ctm',
#  'wom siempr jajaj',
#  'entel lind wom lej mejor compañi',
#  'bien ahi wom pesim machit podr patriarc regal material hac quequ vez mas jajaj hic insert aplaus aqui todosomoswom',
#  'wom mal menor tir mas jajaj primer hag jajaj avis',
#  'bien ahi wom pesim machit podr patriarc regal material hac quequ',
#  'competent gener calid graci jajaj wom via',
#  'fall mundial problem señal wom llev años wom cer dram señal',
#  'clar tio wom mas grand comun consumidor jajaj mal pens',
#  'entel camb wom',
#  'wom movil fij vol raj nefast qls',
#  'oye wom quier hart jajaj compañi jajaj puch escurr habilit bols ilimit tambi minut ofrec zorron entel independient trabaj proyect jajaj sirv',
#  'wom bien usted sig exit felicit buen servici buen calid sig mejor perfect siempr busc excelent servici calid atencion client pesim',
#  'wom feliz cumpleañ graci entreg excelent servici',
#  'wom hac 4 años client usted buen decision cambi moment jajaj arrepient',
#  'wom graci won baj plan tod compañi',
#  'wom excelent servici jajaj cre mism mund',
#  'wom excelent servici ultim red 4g volv extrem lent jajaj pong pil tio wom durm laurel pong igual darksid salud',
#  'wom pues dic llev 3 años señal lad igual satur viv baj net lleg 150 mb baj buen zon rural ido siempr ahi 4g aunqu avec callamp ahy xd',
#  'brav excelent servici brav',
#  'mientr ignor compañi telefon dese hermos dia encant wom amo encant',
#  'metr tobal line 4 wom reg mufins',
#  'wom buen compañi jajaj si mejor señal seri excelent pesim',
#  'wom señal oficin pesim cualqui compañi qued wom ojos cerr encant',
#  'wom yeah pesim si buen compañi',
#  'wom ay cuant odi lleg hac 3 años siempr utilic unic numer wom cambi gust',
#  'wom sorry jajaj enamor',
#  'orgull pertenec empres cambi regl jueg revolucion industri telecomun vam mas',
#  'wom estrell',
#  'jujajaj weon aprovech',
#  'wom geni marketing jaj',
#  'jujajaj weon aprovech',
#  'jajaj mierd compañi sol qued dec buen public jajaj',
#  'wom oh hueon rap jajaj micod',
#  'rap cm wom jajaj micod abusodepod catalinapul catapul',
#  'wom ingeni propagand wom jajaj brav',
#  'wns rap jajaj amo jajaj',
#  'wom genial contingent public',
#  'public hac peg inmediat jajaj',
#  'brav mand nuev wom',
#  'jajaj excelent public pesim',
#  'wom crack jajaj resist plop',
#  'wom jaj buen ataqu defens mism tiemp alud situacion clar explicit muestr personajill cuestion xd',
#  'jajaj grand creativ wom lt3',
#  'cag wom jajaj ment ingeni jajaj',
#  'wom jajaj wom hiz nuev',
#  'jajaj amo wom',
#  'wom asi jajaj poc vec ve ingeni inmediat public chilen',
#  'wom podi fall wom esper jajaj',
#  'ingeni tio wom jajaj',
#  'wom jajaj public wom creador memesrapidis bas tgenial micod catapul',
#  'ingeni jajaj',
#  'equip creativ wom notabl catalinapul',
#  'ingeni jajaj',
#  'wom sec',
#  'siempr atent wom brav pesim brav pesim brav pesim public rrs wom',
#  'micod maner reir jajaj trolle maxim expresion jajaj',
#  'obvi jajaj wom hiz vez brav pesim brav pesim brav pesim',
#  'wom buen mejor red 4g porfis estan contagi competent salud',
#  'obvi jajaj wom hiz vez brav pesim brav pesim brav pesim',
#  'public wom geni jajaj siempr actualiz instant',
#  'amor etern wom jajaj',
#  'wom tio wom fall',
#  'siempr adel tio wom',
#  'wom tendr mal señal jajaj mejor public jajaj',
#  'wom si señal mit buen public seri mejor empres chil port',
#  'convert debil fortalez jajaj dig creativ wom xd',
#  'usted entrand buen form merc twiter jajaj',
#  'wom podi fall wom esper jajaj',
#  'entel mañan mism cambi wom 4 lin aburri',
#  'wom amo',
#  'señal dick jajaj pot clev agenci public si port wom quiz contest general jajaj micod abusodepod elshowdecat',
#  'jajaj mas rap ctmre jajaj',
#  'wom jajaj notabl',
#  'wom jajaj genial wom',
#  'wom monument public wom brav',
#  'ta ble',
#  'wom tio wom mejor señal port crack public',
#  'wom buen podi ser men grand tio wom jajaj',
#  'wom excelent bien',
#  'wom portat wom plan mas flexibl cod cat',
#  'wom si señal mit buen public seri mejor empres chil port',
#  'qlia rap',
#  'wom public deb ser mas genial pais',
#  'sabi wom hari bien',
#  'jajaj won pesa wom buen bon won',
#  'losl person encargad public wom geni jajaj',
#  'wom geni jajaj',
#  'wom juajuanuev asert',
#  'wom jajaj genial',
#  'compañi mortal wom',
#  'jajaj grand wom',
#  'jajaj geni',
#  'wom ciert jajaj public mas audaz jajaj rap contingent da medi',
#  'public wom genial',
#  'wom agenci public mejor vist chilit',
#  'wom hac nuev public brav pesim brav pesim',
#  'jajaj wom hiz vez brav',
#  'wom jajaj cag wom jajaj siempr atent jug',
#  'wom ejajaj siempr dand cuot humor grand wom',
#  'wom si diseñ public president pais mierd seri felic bien',
#  'jajaj wom hiz vez',
#  'sec wom jajaj',
#  'wom jajaj mas wom',
#  'jajaj pas wom brav',
#  'sec jajaj',
#  'wom tendr mal señal jajaj mejor public jajaj',
#  'sac sombrer public wom jajaj culia pesa catapul felizmart',
#  'wom increibl pesim',
#  'wom buen buen',
#  'wom usted gan plat',
#  'equip marketing wom jajaj llev aplaus lej jajaj',
#  'cag wom',
#  'imagin gran part graci wom',
#  'cag wom',
#  'jajaj editor public wom deb ser mejor pag jajaj nadietedam',
#  'jajaj oh ris jajaj',
#  'sac sombrer public wom jajaj culia pesa catapul felizmart',
#  'wom jajaj',
#  'wom dud jajaj empres telecomun señal deficient much part jajaj public sab',
#  'wom jajaj put creativ crest par agarr pal weve famosill cren pod rest',
#  'wom aguant wom equip public',
#  'wom experient ningun dram contrari sal pais 20 pes rigor 190 contrat bols whatsap 3 ap ilimit cer dram sorpres fin mes',
#  'wom mejor jsj',
#  'wom grand wom sincer gran aport comun pais marketing falt libr competent buen onda client callcent gentetc wom llev',
#  'tio wom favor quier gan huawei p30 fiel ud jajaj pag plan correspond jajaj cambi ame compañi pen touchandwom',
#  'wom graci tio wom pulent siempr mejor compañi lml',
#  'wom tio wom nesesit ayud nesesit celul pid jubilacion pen fans numer 1 amo encant touchandwom uncelularparapaul suerteparapaul',
#  'wom quier agradec public emerson sucursal merc x resolvi problem celul compr hac mes medi wom aplaus emerson abuche sucursal ros visit hiz graci emerson',
#  'quier cont experient servici wom pendient moment resolv problem jajaj lueg acerqu sucursal 5 minut solucion tramit jajaj sig asi d verd hac diferent atencion client brav pesim',
#  'denl cervez encarg public wom',
#  'vin apañ amig wom cuart aniversari amig nombr aqui choc frent semej reconoc verd palabr',
#  'wom pong dud lat pas jajaj men buen experient',
#  'situacion actual desastr ap entel vs fabulous encant aplicacion wom definit voy termin port tod lin wom jajaj diner mejor invert',
#  'entel wom va mejor flor',
#  'quier cont experient servici wom pendient moment resolv problem jajaj',
#  'entel wom maipu bastant mejor jajaj sol cobertur jajaj si servici cobr jam vien adicional sab sali',
#  'entel wom cuent pas entel wom tend ningun tip problem nunc señal pas much vec entel',
#  'wom jajaj tremend agil public wom yosoywom jajaj',
#  'wom jajaj cre uds contrat person dia peg ala tel',
#  'jajaj',
#  'jajaj',
#  'chu si nuev grand tio wom jajaj copi mem picant jajaj',
#  'chu si nuev grand tio wom jajaj copi mem picant jajaj ht',
#  'jajaj vez hic jajaj',
#  'wom buen compañi jajaj',
#  'wom lind wom jajaj brav quier soywom jajaj bien',
#  'wom buenisim grand wom usted mejor compañi toc viv mejor experient telefoni movil encant',
#  'wom siempr vanguardi vidasocial consultori vidasocialenconsultori reunionsocial luiscastill',
#  'wom jajaj dram',
#  'wom wom ahor problem encant',
#  'wom tal jajaj mism cambi wom hac 3 años arrepient',
#  'wom dram',
#  'wom problem ahor punt cerr cer dram',
#  'felicit wom 5 millon client orgull ser part años t',
#  'cambi wom llev 3 años ningun problem moment',
#  'wom da pen problem uso wom magallan pro lem dos años jajaj qued señal puert aguirr mas',
#  'wom tb tebg wom funcion sup bien',
#  'wom wom jam necesit ir reclam',
#  'wom sid client casi tod cias unic barat tan penc wom señal discret jajaj mas mal clar jajaj atencion client buen jajaj compar porqueri movist qued señal mism lugar entel',
#  'port jajaj movist hac jajaj tres mes asi cual dos dos dias lleg plan dej internet conplet gig 8me port wom sant remedi cer atad siempr señal internet',
#  'wom raj public brav pesim brav pesim brav pesim brav pesim',
#  'wom tb tebg wom funcion sup bien',
#  'wom excelent cobertur jajaj client jajaj compr prepag incapaz ten cobertur fiest tiran',
#  'wom compart bien encant',
#  'perdi telefon taxi cos obvi recuper numer si habi algun promocion telefon jajaj servici costaner tan mal termin port wom sali plan guaton telefon buen encant',
#  'brill entel tiran parec tendr cambi wom definit deberi hac si va perd much clientel nort iquiqu ahor wom pesim',
#  'contrat plan madr wom weon qued sorprend rapidez bien jajaj viv casi machu pichu valparais arrib po niñ señal fin seman jajaj comparti celu pud salv',
#  'wom estim ivan si iniciacion activ pued portat wom plan rebuen poc luc servici anda impek',
#  'entel pas simil jajaj 15 años client entel sup fielm aburri mal servici dejacion wom jajaj hac 2 años arrepient',
#  'entel not wom buen preci cruz angostur olvidat celul',
#  '7 wom señal internet puebl tiran region tarapac ojal sig abarc lugar zon nort',
#  'port numer wom cer problem metr dan asco incapac solucion problem señal',
#  'ahor jajaj conect trav client wom brav señal establ entel',
#  'wom problem resuelt encant mañan deb lleg equip pesim',
#  'wom si tard anduv dijeron mism wen cambi fre',
#  'wom mir asi andab movist jajaj port wom internet vuel',
#  'wom amo jajaj sol usted sab encant',
#  'client movist cambi wom arrepient bien',
#  'pedaz hil mand cabr gam over',
#  'regres ciud aric jajaj entel nunc funcion internet voz tiran realment molest jajaj 10 dias servici jajaj graci wom servici prepag aric iquiqu',
#  'si jajaj rebaj servici buen calid wom rat',
#  'wom llev casi mes usted moment bien jajaj aun sugier ampli anten señal bien ojal lanc promocion buen pesim manten clientel content dig bien',
#  'feliz hab sal clavistel lleg wom regalon mas viej 20 años clavistel xd',
#  'wom destroz competent',
#  'divert wom utiliz ide molotov instintonacional jajaj rebeldi capital jajaj',
#  'wom solucion problem jajaj much graci atencion',
#  'luz graci naveg 3g graci wom maravill servici encant',
#  'wom guardar tod vid encant',
#  'tio wom pued cont herm chaquetaspark ocup juici final reality elultimoduel',
#  'wom punt volv entel jajaj pag wom perd',
#  'wom coleg wom tambi sac mugr',
#  'wom camp ahor dej sol 3g activ anda bastant bien jaj igual contrat plan ilimit full si tod eh mism jajaj',
#  'wom activ 4g anten chuch tom jaj 3g anda rap asi ir jug depend zon estes',
#  'wom bienven wom pesim jajaj igual cach tecnic jajaj usar gb 3g jajaj acab anda bien 4g ilimit',
#  'movist cueckpesim pesim cambi wom',
#  'wom amo mas',
#  'luz graci naveg 3g graci wom maravill servici encant',
#  'asi funcion internet distint horari 210 pued reproduc pas wom cuest respond sol cran public',
#  'wom nunc clar wom nivel hog ser vtr jajaj si jajaj movist',
#  'amaneci bien mal señal wom centr iquiqu si lleg ten dat movil jajaj sol rat sup lent padondetefuiste4g',
#  'sig mism jajaj respuest part tio wom',
#  'hol wom si van ten numer whatsap vent jajaj posibl 10 130 sol pid rut respond mas',
#  'wom burl atencion rrs whatsap',
#  'wom pued dej quej mal servici prepotent part vendor dentr mall plaz vespuci graci',
#  'wom pas internet anda mas lent rio manj',
#  'put jajaj 4 hor wom deb dec men viv jajaj señal hoy xd wom mejor cobertur renc jajaj si jajaj durar men candy compañi',
#  'dia mas wom da veloc internet domicili jajaj vay empres solucion problem client jajaj lament',
#  'chic jajaj pas hoy general jajaj casi problem navegacion jajaj hoy sab jajaj lej sid experient mas mediocr veloc wom go mejor tem',
#  'wom cad dia funcion peor si servici pued solucion problem navegacion',
#  'mas tres hor señal wom dias arrug cobr bolet enoj',
#  'mas tres hor señal wom dias arrug cobr bolet enoj',
#  'wom pas wom señal 1 dia ningun respuest',
#  'nuev jajaj dia mas jajaj pag mes plan jajaj den miseri servici internet domicili compañi wom',
#  'rabi 4g ilimit jajaj plen capital capaz transmit siqu seri 30 minut internet corr suced wom capitul 30 minut termin siend 2 hor enoj',
#  'wom pauperrim servici ahor tampoc funcion line 5 vez gast tant propagand progr jajaj mejor preocupens gestion mejor anten',
#  'wom pesim ayer compr celul mam hoy mand servici tecnic solucion asum usted fall equip client',
#  'tio wom aller cambi compañi dejem dec mierd servici jajaj principal señal internet lent casc manj peor realiz portabil trav falabellaconect ose atad 18 mes contrat pued hac',
#  'graci wom jajaj red social libr mentir jajaj atencion client horribl jajaj peor clar movist ladron 10gb recarg pued ocup wom',
#  'problem dia señal wom algui mas',
#  'wom lat ten cambi compañi falt solucion llev hart tiemp problem señal cad vez peor asi qued poet compañi cha wom',
#  'wom ladron jajaj estaf sinvergüenz port 2 may cobr primer bolet 14 dias',
#  'wom fraudeladron floj pued solucion problemit jajaj port 2 may cobr empres rat ladron',
#  'wom empres ladron jajaj sinvergüenz estaf',
#  'wom señor cuent pag des seman pas jajaj qued solucion conexion bam 24 hor moment sig igual estar espet',
#  'wom señor jajaj va par seman problem señal zon aeropuert puert mont jajaj trabaj usted viend afect funcion señal limit gener problem comunicacion suced evalu altern jajaj graci',
#  'ayer pap llam dos vec cel son apag jajaj teni tod señal jajaj despu noch lad jajaj llam pas mism jajaj cad dia peor enoj wom',
#  'cambi entel wom pas medi rabi jajaj compañi qla mierd penc jajaj cae jajaj carg pagin jajaj etc consej jam cambi wea hipsters culia penc wom',
#  'wom pas señal quilicu pued siqu llam callcent uds',
#  'señal wom normal malatalc jajaj ultim terribl 4g suert lleg 4 mbps veloc ahor 4g muert 3g intermitent spedtest carg wom',
#  '31 may prim reclam lueg 1 12 pur mentir gan ayud client wom solicit grabacion mas 2 seman aun',
#  'wom cai tramp nunc habi pas cas',
#  'señor wom respuest reclam jajaj ose resum dic sab ap mierd sab sol deb bolet reci emit jajaj acog parcial reclamoc',
#  'wom graci ingresar inmediat reclam',
#  'entel 7 hor line habilit cer respuest part usted wom pas alla',
#  'consult red wom fall internet wom funcion dia',
#  'consult jajaj cyberday compr equip wom s9 128g jajaj lleg s9 64g jajaj llam consult jajaj dic equivoc public pued devolv equip feo encuentr',
#  'empres conchetumar pic señal wom',
#  'wom cre intenet movil ching jajaj hac 2 hor anda lent uwu',
#  'wom problem internet movil mañan llam telefon necesit ayud',
#  'entel pag bolet aun servici 9 hor servici wom uds supong hac show compens client jajaj porq azulit',
#  'wom tendr public creativ jajaj just dia part necesit jajaj carg cag internet metr jajaj imagin ser suel utiliz conten streaming trayect diariospesim pesim encant viudodentel',
#  'calz peg jajaj vi gol metr 5 minut desfas jajaj reci volvi señal wom qlo import gol ctm vam',
#  'wom entel wom jajaj siempr problem veloc internet jajaj llev mes busc solucion dan',
#  'aburri wea plen ciud asi pued wom enoj',
#  'wom problem canal bloqu event deport',
#  'wom acab habl ejecut dio informacion errone gast plat pur enoj',
#  'tod señal 3g wom aun asi veloc shit',
#  'wom pas 4g señal sol 3g',
#  'wom pas señal 4gen quilicur voy cuart mes sol ocup 3g pod carg ver enoj pas tres numer nombr',
#  'pas 4g wom lom aguirr perdi tod señal esper respuest',
#  'wom promocion j6 2 x 1 celular veni fall mio 2 vez servici tecnic quier crer coincident',
#  'wom decepcion servici jajaj contrat plan descuent contrat establec mont jajaj llev 2 mes reclam aun sig hac cobr mayor jajaj llam respuest acercat sucursal enoj diferent servici',
#  'wom si public fe rat tiemp deb exig cambi supongo7',
#  'wom mal wom reclam estadist toc reclam mayor pod',
#  'wom funcion pesim sol wom',
#  'wom public engañ enoj ofrec promocion sal altern compr jajaj llev 5 dias sig tramit respuest',
#  'wom peor qued comunic conmig jajaj llam sab asunt mas facil hac les',
#  'wom di baj servici buen wom avisenm señal 4g nuev tepual jajaj puert mont aeropuert quiz vuelv',
#  'wom mejor señal favor',
#  'wom b net pesim navegacion internet antofagast mejillon mism pen volver siempr',
#  'wom si jajaj trabaj busin esten atent fals public hac rrs',
#  'vergüenz navegacion wom pesim encant',
#  'onda wom hac dias vien cayend señal internet ahor señal complet dej celul inutil jajaj pued siqu llam jajaj sol emergent wom pesimoservici',
#  'si etiquet wom dificil van respond veo jajaj ahi jajaj tampoc lleg señal telefon sol rayit',
#  'che vez llam numer 105 recl wom ejecut dij dab mism reclam wom pesc recl client jajaj todavi pregunt entonc funcion ejecut recl',
#  'wom tio wom llev calet dias 4g terribl dick pens podi ser sector viv dias comprob cualqui lad what chuch hap wom tiowom wom 5g',
#  'onda wom chever ahor pur problem compañi mejor señal pa cambi peruvsbolivi',
#  'wom pesim servici internet pus pajer antofagast igual asco servici',
#  'wom pas exact mism jajaj cambi entel cer problem wom mas barat jajaj señal horribl peor ayud mand unas fot configur celul mas',
#  'wom mal señal hoy',
#  'empres telefoni buen inviert mas anten ofrec 4g plan pued usar bien mas usuari mism anten cad vez mas mal señal nadi hac enoj wom',
#  'wom pesim servici plataform ayud ayer solucion',
#  'wom igual weas pas año engañ promes internet ilimit jajaj final sig siend mierd cualqui compañi',
#  'wom yoe cambi internet anda lent',
#  'wom pued dec cerc wom atravies complej situacion jajaj independent red mov econom pens jam usuari jajaj red pauperrim especial region pas años den bast wom hoy peor opcion',
#  'hoy vez llam mañan mil vec lleg llam jajaj aparec 4g arrib jajaj onda enoj wom',
#  'vist public farmaci patipel puent alto mism line wom critic jajaj atingent jajaj acid direct',
#  'vist public farmaci patipel puent alto mism line',
#  'ser mal señal ap funcion jajaj men deb reconoc mensaj mas honest funcionari wom',
#  'pas aqui wom hac unas seman hag prueb arregl 4g anda peor 3g cerc hospital bas valdivi reclam tipic hic ajust apn jajaj entiend sol telefon anda mal jajaj amig zon wom igual',
#  'sres wom ser posibl mejor señal sector parqu bicentenari pierd constant señal',
#  'veloc ahor wom pesim encant pesim encant',
#  'wom aprend sum minut 40 use 256 aun asi cort servici ladron wom cac',
#  'wom cambi wom estan guat pes vari mas cambi wom',
#  'wom jajaj mism respuest automat jajaj graci',
#  'wom empez caball ingles jajaj ahor pesim internet movil',
#  'pas aqui wom hac unas seman hag prueb arregl 4g anda peor 3g cerc hospital ba',
#  'onda wom hac dias vien cayend señal internet ahor señal complet dej celu',
#  'onda tio wom tan penc 4g',
#  'wom puch jajaj wom cae bien compañi cos jajaj internet wuif lastim',
#  'wom onda señal wom carg jajaj aburr pesim',
#  'wom tan mal señal metr carg ando metr ocurri compañi',
#  'wom estim hac rat veng internet lent jajaj tobal vicent vald carg maldit pagin jajaj rat señal vam mal wom',
#  'wom tio funcion mal 4g clar sector viñ tant anten jajaj aburr jajaj vide pued ver pen',
#  'wom santiag jajaj san felip mal coberturapesim encant pesim encant',
#  'onda wom dos hac internet wifi pesim',
#  'wom dim plan jajaj teni prom 2x1 sub dia pa reclam wom na',
#  'wom ladron mierd quit mas 120 minut consum jajaj siempr evalu bien ahor wom',
#  'histori wom ejecut dic solucion problem dic resuelt nadi pued resp',
#  'realment defraud wom proces prevent asco excus mil cos respond contrat telefon',
#  'mal entrad jajaj intent contact wom cotiz plan empres anex client nuev servici c',
#  'wom carer culia',
#  'entel wom tod mañan perd llam callcent nadi respond servici mas horribl enoj',
#  'wom ofrec pur huev',
#  'wom val callamp mejor cambiat',
#  'wom ten internet chiguay realment horrend mal covertur chiguay',
#  'chist cuent sol wom seri mand encuest dic nosimport',
#  'wom buen señal aqui viv teni prim sali aqui mal señal',
#  'wom cag mal servici van hic portabil 96173531 x santiag servici pag plan ose regal plat wom',
#  'wom preocupens x dar buen servici client',
#  'onda wom dos hac internet wifi pesim',
#  'q onda wom pesim señal internet distint punt stgo present problem tan sol intermitent sin moment cual señal',
#  'wom promocion inmundici sexual',
#  'wom pas mentir dic atent libert jajaj mal trat dan ejecut atent libert pas señal asquer',
#  'estim gran part dia señal asi jajaj cans reclam jajaj sirv configuracion apn reinici equip wom',
#  'wom demasi pot jajaj mal conexion pesim',
#  'wom unic mal wom cobertur señal sal zon rural',
#  'wom hol señal pesim pas restablec servici 10',
#  'wom sin solucion hac reclam',
#  'cambi corre wom hoy lleg cuent corre anterior asi detall minim lat tan chat compañi penc gast mas public mejor señal',
#  'wom pesim serviciomis compañer entel vuel conexiony sal afuer pesc señal enoj',
#  'hol chiqu jajaj compañi telefoni usan gust pens seri cambi pesim wom llev 15 minut esper carg vide enoj',
#  'señal anduv ollo mes tendr algun descuent pesim servici wom',
#  'princip gal desapareci 4g jajaj greci macul h jajaj terribl señal entel interior habi leid recl jajaj indiscut falt señal habl wom jajaj',
#  '12 hor esper respond mal servici internet wom',
#  'ahor volv etic quer cambi corre wom vend dat ahi si va mierd etic',
#  'wom si cerr servici usted hac rat jajaj pag diferent faltant cuadratur ahor lleg bolet servici nuev seried respect',
#  'internet movil wom anda callamp jajaj algui mas wom',
#  'uta wom pas señalhac dias mal enoj',
#  'internet mierd wom 4g alcanz ser 2g pesim encant',
#  'wom seri servici pag parec seri usted',
#  'wom ajo veloc buen ahor uf mal señaln pod siqu abrir miser pagin mal mal dij buen',
#  'wom recibi llam wom indic activ dat roaming aun asi señal asquer definit mal experient internet movil wom mejor quiz algun dia vuelv busc portabil jajaj graci',
#  'wom ql dej ver tranquil part rut 68 jajaj habl orozc vill aleman enoj',
#  'wom engañ consumidor solicit sol cambi titul cambi plan pued hac titul enoj nunc mas def wom sient estaf',
#  'ahor quier respuest wom si mal servici tendr rebaj pesc weon penc conchadetumadr',
#  'señal wom andad reverend callamp',
#  'seman wom pod habl ahor sid pesim servici',
#  'wom pas veloc internet vregion sup lent 3g 4g pas quevuelvaeltiowom',
#  'wom tip march produc orgull wns enferm',
#  'wom malisim señal nort chil santiag internet cobertur llam telefon rest acompañ si jajaj desastr wom nosecambieawom conect santiag iquiqu antofagast copiap laseren',
#  'wom 7pm ayer caid señal propi wom hoy sab volvi regul comun mont patri instal anten falt comun 2 local 1 anten propi rest repetidor cias',
#  'wom c aun servici pas mas 30 hor servici voz perd pacienci exij solucion urgent s12089360802',
#  'wom señal concepcion jajaj ocurr señal',
#  'mierd cambi wom enoj',
#  'wom s jajaj señal mal wom pesim',
#  'wom s jajaj internet diaspesim',
#  'pas tio wom 4g peñalol pesim net',
#  'wom señor problem señal internet hac cuatr hor pas',
#  'wom mal señal internet puert mont vari dias asi',
#  'pur vuelt mas si iban dar rebaj mal servici wom iran infi maldit',
#  'wom juev ingres solicitud plaz maxim resolucion 12 hrs jajaj ayer pregunt sucursal dijeron deb esper 12 hrs jajaj pregunt hoy dic solicitud ingres mal deb esper 12 hrs mas jajaj mierd pas',
#  'wom mejor señal 4g verdader mierd igual caus apoy jajaj orgull sac carrer venc enfermed',
#  'entel wom pen jajaj verd servici hoy',
#  'wom devuelv plat chip compr sirv',
#  'pregunt jajaj wom dign darm respuest cantid twets reclam mal servici internet ultim seman enoj',
#  'wom crei sol pas enoj',
#  'pag 25k plan wom mierd servici internet wom cre mal decision hab cambi',
#  'segu mism wom quier descuent bolet mes enoj',
#  'poh wom van mejor infraestructur lider portabil jajaj traduc hart usuari jajaj mayor ingres van invert mejor señal unasc wom malaseñal',
#  'voy segund dia wom señal anda reverend viv pued renunci jajaj',
#  'wom modem anda extrem lent jajaj punt carg sol pagin jajaj onda',
#  'aca esper wom tant pong camion prof estan grit hac seman comun educ ups deber vend',
#  'entiend wom ofrec gig minut libr jajaj si conexion internet jajaj llev mas dos seman extrem lent peor nadi da respuest concret respect',
#  'marchadelorgull aun dan cuent movimient lgbtq hac rat convirti pur marketing bast ver twit jajaj especial wom utiliz tem social vend plan lat aun den cuent manipul realid pen',
#  'horribl señal wom aric jajaj independient lug jajaj cuest carg 4g jajaj mas 40g plan jajaj lent',
#  'entiend wom ofrec gig minut libr jajaj si conexion internet jajaj llev mas dos seman',
#  'wom abus jajaj abuel pag 90 7gb pag mas 30gb pesim enoj',
#  'wom cag ten mal señal llev 2 mes señal pesim andan ahi clar pesim',
#  'wom algun moment red 3g usted funcion tod señal pued hac spedtest',
#  'odi wom vid tant punt servici plen santiag',
#  'wom gent mal capacit',
#  'pregunt si wom har hor servici jajaj deb fall jajaj sol envi mensaj',
#  'wom pas señal telefon descarg 6 pm 8 jajaj enchuf ahor señal jajaj dic sol emergent necesit ayud',
#  'wom hac obten buen respuest buen señal part usted',
#  'verd entiend señal wom dias trabaj ovall red tod intens poc tas baj navegacion',
#  'wom dia intermitent señal internet',
#  'wom dan original inov copi cuadr cuadr escen mentir verdader gran conedi acion jam cameron 90 marc ser coherent',
#  'wom asi mism servici 190 120 hac mes jajaj podi sincer pas',
#  'wom hol pesim hac tiemp vien disminu calid señal pesim encant',
#  'esper hoy pong internet oficin ire b edifici wom abandon dej celul ventan asi pued wn tio wom chever ser pag plan empres quier bien',
#  'quier ser wom public cobertur lleg bellsouth',
#  'wom van ten roaming plan inclu estan qued atras',
#  'mas encim quier pon reclam inutil pagin wom carg naveg 3g',
#  'wom cres 2 dias tiemp respuestal ayud ser necesari fin mes cambi compañiapas ser mejor peor',
#  'wom tard ayer doming lleg servici mal rat hic pas dad go llam carter ampli client pesim encant',
#  'wom lent respuest requer tiend wom',
#  'wom vayans chuch jajaj perdi fre fir lag',
#  'wom onda señal compr bols teni internet final mism andar internet jajaj whatsap mand',
#  'diri wom vomit maxim',
#  'wom mierd señal santiag pesim',
#  'wom quis embauc plan cobr dem ud tendr algun plan ofrec pen',
#  'wom pas internet anda mas lent tortug',
#  'wom incompetent jajaj inoper jajaj ineficient dia 18 reclam jajaj atend mas 6 person aun dan solucion pesim servici client wom',
#  'wom pur bla',
#  'wom pesim señal provident',
#  'wom trat dw ver wlnpart pesc señal jajaj mal ahi jajaj mal jajaj',
#  'wom pas tio wom señal hoy encant jajaj pong mediocr siend chever',
#  'encuentr comun san javi jajaj region maul 0 nul cobertur internet pesim señal jajaj mejor dich jajaj weas',
#  'wom aca suced pasads 0 wifi reverend',
#  'wom rien competent car inoper capacit bien gent ver si respond sin csm',
#  'wom oye wea hac par seman internet funcion horribl jajaj noch red social horribl arregl wea lueg',
#  'señal wom asquer jajaj horribl jajaj nefast',
#  'wom mism mierd cobertur asco internet',
#  'ayer 23 hor puq desconect mund wom hac mas men medi hor volvi señal 4g men clar apur asunt foa',
#  'wom dej envi dm jajaj ten anda pesim internet lad 4g 3g',
#  'wom acab port dos lin pesim señal pesim encant',
#  'wom ten internet chiguay realment horrend mal covertur chiguay htps',
#  'wom lumbag ciatic tir cam medicament pens amp pag ctas',
#  'wom uds dan honest ofrec gig libr siend 50gb public engañ wom conchetumar',
#  'rew señal wom',
#  'wom pas internet mas lent boler hoy demor mil carg cualqui pagin',
#  'wom contradic promocion jajaj',
#  'wom problem usted jajaj abril esper devolucion diner equip comprey sali mal jajaj voy hac reclam sernac',
#  'wom hol calid señal minut av itali jajaj provident dos barr desiert camp montañ corazon barri itali pued explic jajaj favor',
#  'wom tio wom arregl señal dej sub weas',
#  'wom pas señal cabr pal loly perrit',
#  'wom jug pokemon go habl mas uso net movil',
#  'wom estim aburr servici client necesit ayud jajaj solucion algui hag',
#  'wom decepcion pesim servici lluev dia siguient suert 3g sirv llam mal ide pas plan famili empres pesim',
#  'wom mas fals red social gratis dan compr bols pesim consum gb men 2 seman',
#  'wom señor año antepas hic uso d 1 fot ci habi utiliz dar d baj servici d sucursal virtual pack hog ahor deud telefoni movil d wom entel antecedent estan fiscali necesit solucion',
#  'wom pesim ma atencion client jajaj pedi chip nuev ir 3 vec sucursal hoy aun solucion problem',
#  'wom escribi pued ayud',
#  'wom avis sol 50 gig libr mas jajaj asi despu acab culp client ler letr chic enoj',
#  'wom pas hoy señal entran llam curic',
#  'wom señal hoy entran llam jajaj pas jajaj curic',
#  'pas señal wom qued señal metr sector mal señal vuelt mal quier pur cambi ningun compañi d mierd m llam jajaj m llam ofrec plan 1vez seman',
#  'onda mal señal wom llev dias problem pesim encant enoj wom',
#  'compañi buen cobertur maipu chat wom pesim señal va mal peor necesit cambi seteniaquedecirysedij',
#  'pens mism moment cambi wom jajaj advirt primer mes estari bien jajaj despu lamentari cre hoy mes comenc lament jajaj añor volv',
#  'tio wom pas señal aca santacruz anda pelot help',
#  'wom lleg punt aren hac dos hor señal favor ayud',
#  'wom hol jajaj servici telefon algun problem señal cas aisl',
#  'wom servici mas mal jajaj 3 vec sucursal llam servici tecnic 5 vec jajaj inicial dijeron medi hor estari resuelt jajaj hoy dia despu dijeron 72 hor pesim servici',
#  'wom dia lun indic plan sald realiz llam llam dia hoy dic minut dispon aplicacion indic 186 min necesit respuest solucion urgent',
#  'wom algun departament especializ fraud llev tiemp esper respuest fraud respuest',
#  'wom si tan sol buen cobertur qued señal comun viv final pag servici medi motiv suficient volv',
#  'wom señal cobertur talon aquil',
#  'ver tem esper ser inoportun jajaj empres wom equivoc dos ocasion men año line jajaj dig equivoc dec ment jajaj entreg informacion fals public engañ jajaj pued hac',
#  'tio wom mient vec señal isla jajaj normal aol funcion si vien isla pascu usen entel',
#  'wom estim jajaj deb respet jajaj deberi selecion bien personal jajaj dia ayer 25 juni personal envi cauquen capt portabil trat pesim jajaj garabat quis port numer jajaj rot quer ver',
#  'wom problem señal jajaj sin cort servici llam aun qued mas 180 minut',
#  'wom pregunt si isla pascu teni cobertur jajaj dic wea jajaj lleg isla servici asi compr chip entel',
#  'wom stgo funcion jajaj aqui nort asco señal clar funcion mejor imaginat',
#  'wom mal wom plan santiag 4g full jajaj viaj entel nunc fall',
#  'tio wom tan mal señal plen centr santiag altur pis 5',
#  'wom sres jajaj nunc 4g ningun part jajaj',
#  'andad put dia pic internet wom',
#  'wom pas mism dieron ningun respuest',
#  'wom som vari afect insist minut si',
#  'wom cay vez internet san bernard tan irregul servici',
#  'wom ojo public engañ',
#  'wom wom cer respuest mientr sig pod llam',
#  'wom necesit ayud jajaj internet movil anda cad vez mas lent hac par seman llam hic algun especi limpiez cambi qued esper jajaj salud',
#  'wom contrat plan 1690 jajaj llev 2 mes cobr 2490 jajaj wom envi contrat 1690 sig cobr 24 mil estaf',
#  'wom crest quier ver anim metr buen guaton ql jajaj nunc señal csm',
#  'wom mierd jajaj music fiel auditor necesari potenci gener ningun conten min',
#  'quiz cumpli record 1 dia wom jajaj servici mas mal pens podi ser peor cia top gentetuv dar baj line pag servici entreg barat mal',
#  'wom red pued ser mas lent',
#  'wom ciert jajaj servici atencion client realment pesim',
#  'wom port jajaj mal 4g jajaj hac 3 años bien jajaj degr servici',
#  'wom pas tan lent servici internet',
#  'dios servici deplor wom internet intermitent',
#  'wom respet jajaj naveg telefon cul cad rat deb selecion oper ningun solucion result jajaj telefon compr usted',
#  'cobertur wom line 5 metr estacion grut lourd sant ana tan mal',
#  'wom pag cuent aun restaur servici favor regulariz necesit urgent 569574958',
#  'wom ingres estim jajaj acedi pued hac public jajaj tambi adjunt tod prueb cas llev mas 5 dias solucion ingres dat entreg subtel wom',
#  'quier port wom estaf gb hag',
#  'wom pregunt sig merc si regal servici chist mund cambi',
#  'wom seri buen mejor promocion client va enfoc client nuev terribl',
#  'pasand contig wom voy line 1 ahor caes pon lent pesim encant',
#  'wom problem señal ayud',
#  'wom mierd wom',
#  'wom hol jajaj problem celul jajaj señal',
#  'wom 4g pail jajaj 3g mas lent pep roj',
#  'hueon herman acab compr celu wom inhabilit numer jajaj llam wom dic pued atend trabaj 9 qued servici mañan jajaj cer preocupacion client',
#  'wom espant atencion telefon jajaj esper intermin dec servici intermitent si llam dic nuev hac perd tiemp hac igual configur mas remat ningun solucion',
#  'wom sirv ten contrat plan 4g si usted interrump servici avis client cambi',
#  'oye wom onda señal sup lent sector manquehu',
#  'wom mentir wom mentir va gig puefoy ver tiemp',
#  'wom mentir jajaj envi promocion via msje nunc pued compr sub altern jajaj mil recl dan solucion jajaj public engañ siempr',
#  'sup cuatic escuch comentari homofob vendedor empres predic divers wom ser sol comercial',
#  'wom pas señal tio wom ajo jajaj pued llam suert internet',
#  'wom pued ser mas lent test pued hac mostr desastr red',
#  'horribl empres wom llev dos mes tap sms spam reclam mas diez vec promet van mand mas mensaj sig lleg rat mient descar',
#  'pas wom red veloc pelot',
#  'wom sig aparec sol llam emergent wom pesim encant pesim encant pesim encant',
#  'wom reconocel chip jajaj quier dec pag cambi chip pued ir hoy lluvi jajaj pues discapac motriz pued caer wom respond ladron',
#  'usted tambi wom servici telefoni movil dat ayer viern 18 hor servici',
#  'arrepent hab cambi wom mierd señal santiag enoj',
#  'trist frustrant wom quit numer pag jajaj regulariz deud aun asi dej numer plan port compañi much desilucion sol pens ojal nadi mas trat wom',
#  'wom estan hac public informacion engañoz',
#  'wom letr grand inoper min call cent wom pic ide hac ahi jajaj chuch quw inutil weon',
#  'nadi wom respond jajaj dia mal servici jajaj supong qur descont',
#  'onda señal wom internet jajaj señal',
#  'final wom igual peor rest vuelalt',
#  'wom hol jajaj problem señal aca jajaj pued ayud',
#  'wom pas señal anda tan mal vari punt santiag jajaj estan anten caid bien irregul internet',
#  'wom tip march produc orgull wns enferm',
#  'supuest wom da 4g ilimit jajaj pued naveg ningun pagin usar ningun ap dic pas cuot navegacion entiend ilimit',
#  'wom si jajaj parti caball inglesahor desastr',
#  'wom hol hic 3 lin entel wom sab arrepient esper termin 20 dias irme',
#  'wom si vuelv stgo viv puent alto jajaj altur mall tobal lleg 3mb wum',
#  'wom funcion pelot coquimb enoj',
#  'wom funcion mal lad',
#  'wom ajaj part funcion bien',
#  'tio wom pas internet tan penc demor carg imagen va mas dos seman asi osorn',
#  'wom reclam xq pued usar plan x intermitent señal telefon internet hac 2 seman constat moment indic senti jajaj habi incident instal despu respond baj perfilwom',
#  'wom qued sup plan si pued usar respond neg constat x telefon cad vez llam justific intermitent cambi cambi aparat soberbi falt solucion respuest',
#  'llam pa solucion tem telefoni wom llev 30 minut esper x oper tan sol dickinthey',
#  'wom mierd wom mal jajaj negoci compañi 2 años chip funcion bien jajaj siguient echa perd chan deb cambi chip cost 7mil pes iva inclu brav aja mierd pesim',
#  'seman pas engañ mam chip gratis port wom mal pregunt devuelv sald habi recarg viern dic van 2',
#  'wom dm sirv envi respuest oficial corre envi jajaj dic incident tem menor circunst hor servici telefoni internet contrat deb ser permanent',
#  'wom favor arregl señal jajaj mas 2 mes mal dar ultim seman cambi plen stg',
#  'wom arregl 4g plen centr stg verguenz',
#  'oye wom descar jajaj rob 20 minut plan pobr viej echaron culp ap pas pa rasc',
#  'wom peor sucursal virtual vid si',
#  'wom tod empres burl subtel hac quier jajaj tant deferent empres despreci usuariosqu pong pantalon suvtel jajaj fiscalic acept rob compañi jajaj mied',
#  'wom ir oficin cambi chip enoj jajaj atiend ahi mas gentil pues pregunt nuev model movil parec durm atiend mal gan enoj oficin estacion central mugr 120 hrs wom vean whatsap',
#  'wom respond',
#  'sesionesubterran wom hac mes señal wom horribl mal talcahuan mas 3 años pag 2 plan servici orto help',
#  'sesionesubterran wom hac mes señal wom horribl mal talcahuan mas 3',
#  'put lleg señal wom isla parais lleg rein chist cruel',
#  'conoc rob cel compañi wom llev esper 1hr atiend bloqu telefon 1 hr algun medi pesimoservici',
#  'wom m tantoy hac mas 1 mes m cambi plan porq m venci 2x1 hac cambiotendr ir pel mañan sucursal ver onda',
#  'wom holaestoy problem señal cas comun renc ocurri help',
#  'wom teni 1 torne dps d mes uso dieron baj numer dieron person x contrat numer chip prepag x usa hac contrat x unas seman dps dim baj wom jej seri',
#  'clarisim wom sirv',
#  'wom hac comercial progr jajaj casi intoc',
#  'wom apoy danil igual plen viñ mar jajaj pag tres plan jajaj mism señal mal',
#  'wom empres deb mas prolij resolut line necesari ir socursal tiemp ir enfermed trabaj esper mejor realment informacion call socursal nunc concuerd',
#  'wom tambi esper mejor cobertur siempr escud ley abstract nadi entiend sol lucr empres client sol oblig pag derech apelacion',
#  'wom ahi ser bien tras años cambi xd',
#  'wom respet descuent 25 dijeron qw aplicari lin contest encuest llam 103 adem person qw atendi parec contest cam peor aun jajaj despert jajaj dic deud',
#  'llev dia señal wom sol llam emergent desesper wom ayud',
#  'wom hey pas señal pudahuel jajaj qued internet señal celul colm pas port compañi',
#  'wom fals total jajaj vez hic supuest indepent red caraj jajaj pesim señal jajaj internet deplor perdi señal absolut are trabaj miner collahuasi asi 3 años antigüed port compañi',
#  'wom port entel lleg bolet proporcional lleg mail part usted dic si pag 15 juni teni rebaj pag hoy sig cobr',
#  'wom favor par mem',
#  'wom lent cos',
#  'internet wom pesim',
#  'wom saturacion señal po pas event masiv',
#  'wom weas cag',
#  'wom mism webiadisim',
#  'wom ahor salt tod mantien anten wnes segur reportabilod señal',
#  'wom acab dar cuent igual coleg wom igual jajaj deb ser general sol 3g suert',
#  'wom mejor servici d telefoni celul desgraci 96173531 mal cobertur navegacion llam remal',
#  'wom aun esper hag efect portabil dijeron tard llegari mensaj activ cambi jajaj ocurr llam ahorit jajaj cae llam 103 numer fij exij respuest inmediat telefon',
#  'wom problem señal cas internet',
#  'gent cre plan libr wom ilimit dijeron hac 1 año medi jajaj asi jam ilimit jam libr ilus',
#  'mierd wom hic cambi plan dej si internet',
#  'wom result solucion requer client pid monton dat dan respuest incoherent repit mism pid respond jajaj cobr mas rembols jajaj llam sig mism plantill respuest tip jajaj perd tiemp',
#  'wom expliqu bien jajaj hac mes señal mal llev 3 años wom habi ningun problem',
#  'vari dias problem internet wom malisim señal 4g pag bolet mensual 80 mil pes jajaj pens seri cambi compañi',
#  'suced señal comun san bernard jajaj altur jorg alesandri 1080 wom',
#  'wom cobertur wom incahuasi vallen',
#  'pas red wom permit descarg',
#  'teni much fe wom cad dia señal peorqu lastim empresari mejor represent competit',
#  'pas señal tio wom mal ahi wom',
#  '1 hor red cobertur flor wom',
#  'funcion instagram jajaj facebok wom señal 4g dat movil activ mal wom cay',
#  'wom hol señal mañan jajaj ayud porfavor',
#  'wom abren jajaj carg public nuev muestr fotos0ks dic arribamal much anten nuev jajaj funcion c',
#  'wom respond twit envi mejor',
#  'wom respond twet mejor arregl señal problem apart red social',
#  'hol wom decepcion pen telefon naveg aunqu dic voz4g',
#  'wom llev hor trat contact usted dan respuest servici ayer pued siqu llam telefon envi mensaj intern tod part esper dign respond',
#  'q pas servici internet movil señor wom llev 2 dias servici enoj pesimoservici',
#  'wom pas cas cont dias regres entel jajaj pesim servici wom cas',
#  'anda peor si wom jajaj llev casi 2 hor trat transfer pur 10 luc',
#  'wom pas internet tan mal',
#  'ups wom mal ahi hac cambi chip deterior jajaj independient caus client pref acept dar baj plan',
#  'hic cambi plan 3 4 lin ayer 180 ahor pas 19 hor servici lin jajaj pued llam naveg unic respuest esper 24 hor mas si arregl wom',
#  'ups wom mal ahi hac cambi chip deterior jajaj independient caus client pref acept',
#  'wom aweon',
#  'wom pod dejart señal plen provident wom wom nadi da men cobertur',
#  'pal blanc segur wom asegur suert corr 4g',
#  'quier ler histori terror vean funcion servici client wom consej nunc cambi compañi peor pued exist hil wom',
#  'wom algun problem dificult envi archiv',
#  'metans respuest automat copi peg tan inutil chuch jajaj posibl solucion problem internet ayer hag arrepient hab cambi wom clar enoj pesim',
#  'metans respuest automat copi peg tan inutil chuch jajaj posibl',
#  'aqui lleg ahor once vec solicit mism jajaj once vec wom asegur envi mas public once vec sid mentir wom spam',
#  'estan mint dm ahor dic llen formulari molest sernac si hic dos vec usted sig mand spam reconozc vez interes respet ley wom',
#  'si jajaj vean joy respuest estan dand dm burl acas wom spam wom',
#  'wom llev seman internet movil numer puntual cad vez comun whatsap tom pel jajaj pued solucion problem',
#  'wom pas callcent jajaj llev 3 hor trat contact jajaj sol dan info whatsap facebok bla estan caid jajaj cort llam',
#  'wom jajaj camb entel jajaj aburri mism jajaj wom pag men jajaj señal horribl jajaj salud pesim',
#  'wom onda señal wom cambi hac 1 mes funcion hoy',
#  'wom cobertur cel muri mañan tip 1 ahor aun llam jajaj sol emergent jajaj normal pued hac ayud tio wom',
#  'wom internet hog wom anda mal algui mas problem lun noch',
#  'wom huawei dieron dcto solicit cambi rembols valor smartwatch fall fabric wom neg hac',
#  'wom dia pesim señal pesim encant',
#  'jajaj mal posvent chic list wom',
#  'wom asi viaj dias tobal puent alto jajaj red jajaj test pued hac demostr desastr señal ahor ningun solucion part uds cre hor hac reclam subtel',
#  'wom necesit habilit llam multipl telefon 2 37 76 0 103 respond',
#  'nuev wom dand cach internet pag ultim factur cambi pesim calid señal mejor ahor lament peor',
#  'wom ser ahor vez señal pus inest jajaj fom',
#  'wom compañi cobr tan car jajaj inviert deb favor client',
#  'wom asi jajaj tal cobr servici',
#  'nuev wom dand cach internet pag ultim factur cambi p',
#  'wom hol jajaj problem telefon recib llam',
#  'wom buen señal hoy pas sup lent internet celu wom',
#  'wom arregl señal rauc jajaj internet lentisim',
#  'mierd intern wom funcion wom',
#  'wom val verg wea dir zon deficient',
#  'onda wom llam 103 cort llam necesit modific plan pued wom',
#  'molest muchisim wom invad mensaj promocion compr mas voy port wom cort',
#  'wom pas señal 4g cambi wom',
#  'wom servici 4g jajaj inest sol 2g baj señal centr cuid siempr buen señal llam 103 lin satur 9 minut esper cort',
#  'llam habl vari vec problem navegacion wom aun solucion jajaj dich ok med saturacion anten problem etc pag dia servici 3g proced',
#  'wom llam dia medi propagand pus quej molest sig',
#  'llam habl vari vec problem navegacion wom aun solucion jajaj dich q',
#  'internet movil re penc dias jajaj onda wom',
# ...
#  'alo wom señal ningun tip 06 mañan hoy jajaj siqu llam emergent jajaj encuentr incomunic algun solucion',
#  'wom mierd wom volv clavistel pesim',
#  'wom parec increibl solucion rap sistem deud debi liber plaz maxim dos hor',
#  'wom conect pc pud recarg bam hoy celul resuelvanl fa cad vez qued dat mism tem enoj',
#  'wom reverend ogt hue llev reclam dia 1 aun solucion 5 millon usuari manten red hue wom mejor anten poh jajaj yend raj inviert tambi',
#  'wom personit wom llev dia servici ayud',
#  'amor clav crist wom dej envi tan intens llam portabil enoj',
#  'wom mejor arregl cag señal dej vend gent weas',
#  '4g wom funcion rio manj',
#  'wom llev 3 años wom cambi jajaj ultim tiemp asco tan barat plan',
#  'hey tio wom pas calid señal llev dias sol 3g inest caist lad oscur',
#  'wom nunc arregl problem line jajaj servici 3 dias jajaj dijeron 2 hor jajaj despu 12 despu 72 jajaj pesim servici',
#  'naveg dia noch tio wom rechaz reclam wom',
#  'wom public orient pur wns cren alumbr diferent',
#  'wom public orient pur wns cren alumbr diferent',
#  'wom castig jajaj impondr mism calid servici',
#  'wom jajaj tendr mejor cobertur señal limach ejempl jajaj quillot jajaj mejor primer servici calid jajaj ten 5 millon client asegur buen servici',
#  'mal suert quebr pantall moment hoy sol darm gust mostr ganador compr wom',
#  'wom mio ayer mal',
#  'wom compañi telefon mas agres pais burl nacional mil vec mejor red pais 3 mund',
#  'wom llev dia pod realiz llam mierd',
#  'wom enferm unic sab dec pid algun explicacion dej dmes dic dej curriculum llam cuest comunic inmediat person afect',
#  'wom concuerd comentari tiemp part señal guate pesa jajaj van bien encamin ser nuev clar jajaj',
#  'wom jajaj año pas van coloc anten mejor señal pas jajaj sector limach san alfons pesim señal ose jajaj quillot san pedr jajaj sac ten 5 millon client import cobertur',
#  'montañ señal perrits pen tod seman negr comunicacion min inviert luc public anten ctm',
#  'wom quiz lleg suficient señal jajaj celul jajaj da mism si rap jajaj si tod barr señal apest',
#  'wom line 1 hac bastant rat 4g jajaj onda',
#  'wom entonc jajaj si penc wom',
#  'peor señal wom',
#  'hol wom agradezc informacion plan cambi celular ofrec jajaj encuentr colombi asi dificil acept servicioscom hag sig satur corre graci',
#  'wom prefier irme pres ten wom jaj',
#  'wom vergüenz mas dos seman esper equip lin empres unic dan corre calmant solucion rien client',
#  'wom tres seman envi equip lin sig riendos cer respuest vergüenz burl client',
#  'wom nadi da men jajaj 5 millon vacun',
#  'wom 4g llev dias funcion pesim jajaj reclam ofrec descuent 15 bolet jaj wom jajaj quier descuent jajaj quier 4g decent',
#  'wom sirv ten ap funcion pas wom chever pesim',
#  'wom cag recarg',
#  'wom igual compañi unic gust weon pag despu met pic ojo',
#  'wom val realment callamp weon estan desepcion',
#  'wom llev tres años uds llam vari ocasion equip nuev 2da line televent val callamp',
#  'wom televent mierd',
#  'wom 4g llev dias funcion pesim jajaj reclam ofrec descuent 15 bolet jaj wom jajaj',
#  'suced wom cay señal 4g laseren anda lent',
#  'lecion aprend wom barat siempr sal car si compr telefon renuev cas hag compañi jajaj servici tecnic nefast jajaj respond equip aun encuentr garanti wom estaf',
#  'onda wom celu derrepent conect mas señal qued valdiviacl wom',
#  'wom pas wom señal pesim hoy temuc crest 4g suert 3g medi mor salt fallawom 4gca',
#  'wom mism internet',
#  'aburr wom internet callamp jajaj mas encim 7 tard internet diacon suert ocup 20 minut mes calladit pag 17 luc servici weas',
#  'wom pto mont mism pesim encant',
#  'wea señal wom va 30min cag moment wom pas temuc',
#  'onda wom pesim señal internet jajaj barrit h jajaj amig coleg wom coment mism cuest mund carg pagin',
#  'wom pesim servici client wom dias trat den solucion enoj',
#  'onda wom pesim señal internet jajaj barrit h jajaj amig coleg wom coment mism cuest m',
#  'wea señal wom va 30min cag moment wom pas temuc',
#  'hermos experient wom llam numer 6 mañan jajaj enferm wom',
#  'wom ayer pid solucion problem jajaj super situacion si respuest solucion jajaj cambiar compañi numer wom',
#  'vergüenz wom',
#  'wom pesim servici client mas seman resolv problem sincronizacion cuent 3 portabil jajaj peor decision',
#  'wom mand promocion product si dich product stock tiend pesim encant pesim encant pesim encant',
#  'wom buen equip ojal nunc salg mal servici postvent horribl',
#  'contrat internet wom dias problem trafic dat pued trabaj internet ofrec gig pued usar',
#  'wom onda 4g port dia ayer demor mas pesim',
#  'contrat internet wom dias problem trafic dat pued trabaj intern',
#  'wom asi dan gan contrat ejecut tip vocabulari dej arto dec',
#  'wom fals loc',
#  'wom llev mas dia pod realiz llam jajaj sol respond solicitud plaz 12 hor respuest aburri contact 105 odi',
#  'wom sol respuest polit correct solucion cerosolucion lapeordecision paseogratuitoalclient',
#  'lecion aprend wom barat siempr sal car si compr telefon renuev cas hag wom jajaj servici tecnic nefast jajaj respond x equip aun encuentr garanti wom estaf port',
#  'wom jaj supong wom dich plan cuent control jajaj ose prepag ojal viaj llev sorpres deb carg plat jajaj pes pag 30 mensual 2 plan jajaj ultim hor avis moment activ roaming jajaj ose mierd wom',
#  'wom pf jajaj ayer pesim encant',
#  'wom tio wom jajaj port entel jajaj sient voy mas lent amig aqui present',
#  'wom ah penit',
#  'wom problem internet sms jajaj pued envi servici jajaj adem solucion ofrec mierd jajaj pid pag bolet siend llev 3 años usted si pag solucion problem',
#  'wom soport mejor dich wom burl client ojal usted mejor atencion',
#  'wom pagin wom caid queri pag cuent jodi jajaj pued web ap',
#  'wom sol atencion client solucion mal malservicioalclient sinsolucion faltaeficient',
#  'mini hil mal buen rat servici wom',
#  'wom visit 2 tiend busc huawei watch gt stock peor pued ver stock line adivin jajaj algun info',
#  'wom hey pedi cambi numer dieron recient usad llev 2 hor respond whatsap extrañ enoj',
#  'wom ser ahor jajaj reci part demor 3 mes devolv plat',
#  'dign pag deud apweb funcion tio wom hag argo',
#  'wom contrari jajaj llev seman problem internet solucion chaowom',
#  'wom fals loc',
#  'wom ser ahor jajaj reci part demor 3 mes devolv plat',
#  'oig tio wom anunci reloj promocion ningun lad jajaj cos',
#  'wom terribl dio respuest',
#  'wom aun respuest pregunt jajaj equip pued renov ingres numer corre nadi llam escrib renovacion equip llev tres años usted cer servici post vent mal',
#  'wom qlia chat empres qli mierd jajaj solucion pesim enoj pen',
#  'wom pas jajaj 5 millon jajaj anteseraschever ahor ando orto conc jajaj 0 jajaj 28mb sub jajaj voy pod ver porn',
#  'wom estim pued encontr modul permit port prepag prepag tom prom 15gb dic sol plan letr chic uds',
#  'wom clon tarjet vis sucursal general macken real vergüenz ejecut ladron exij devuelv rob',
#  'entel 5 ejecut 3 are especializ aun problem internet jajaj extrem lent jajaj hac 1 seman jajaj asi trat client mas 10 años jajaj iphon x pag plan 4290 wom plan portabil favor',
#  'oye wom toy chat mbytes vien recarg prepag jajaj dur men peo canast pued aprovech nunc quier ahorr oblig usarl sol 5 dias enoj udsest puebl vacunaspesim',
#  'señal mierd wom',
#  'wom desastr atencion hac contrat fals rut siqu dan numer telefon supuest contrat mand contrat ladron',
#  'despu 21 hor calid wom asi mes aburri',
#  'wom reci port internet vol jajaj ahor tristement pen',
#  'wom lament dieg jajaj sup dolor cabez tendr',
#  'acuerd jajaj wom habri repet uso autoriz espectr emergent flor estacion central agenci gubernamental acus jajaj adem utilizacion espectr jajaj explotacion vend plan ofrec servici dich frecuenci',
#  'wom parec falt respectr',
#  'wom condor espectracul',
#  'wom pas red 4g antofagast cae cad rat',
#  'wom vergüenz lleg punt logr vend mas',
#  'wom buen dia jajaj d ayer lleg mail ofert renovacion equip aniversari interes jajaj click sali mensaj mañan ayer contact ud aun sig esper mal ahi empres client plan',
#  'wom despu wom inici vi oblig cambi compañi jajaj cay señal 4g jam volvi cer compromis empres 3 lin',
#  'compañi wom fiasc 2 dias pel respet promocion respuest vay sernacs pas',
#  'wom dej wei spam molest fastidi wospam',
#  'wom habl sobr 5 millon client 4 años jajaj mejor enfoquens fideliz mejor cobertur pesim',
#  'consej dia nunc port wom mierd señal',
#  'wom dic jajaj amig amarr proxim año plan llam reclam dijeron zon bord signif jajaj pregunt jajaj dij jajaj acostumbr tendr señal dia encant',
#  'wom jajaj contrat plan compaño pierd numer nom hagal jajaj servici wom malisim respuest post vent chist',
#  'wom sig ahi pur marketing pesim servici',
#  'wom ciud pesim jajaj imaginat muev radi urban pesim encant',
#  'wom ningun brill lanz promocion reloj ningun tiend jajaj enter penc',
#  'wom injustici mas grand plan pen',
#  'wom señal verdader mierd jajaj llam sal call contest',
#  'consej dia nunc port wom mierd señal',
#  'camin sucursal renov celul lleg dic asi supuest promocion aniversari parec ser fals public engañ wom veo ningun lad dig cuot inicial',
#  'si pag 1 luc plan saldri 20 jajaj rat ido wom impresent 4g pued ver tel internet',
#  'perdi mejor carrer año formul culp odi wom',
#  'wom pas mism pued llam',
#  'ser telefon wom bodri 4g señal pesim carg histori insta',
#  'ser telefon wom bodri 4g señal pesim carg histori insta',
#  'wom deberi preocup manten buen funcion red complet nivel nacional pued ser lug vay jajaj report incident',
#  'wom prometi 4g nunc pas 3g jajaj cad 5 min pas period figur servici contest nunc jajaj hac carg discurs lad vers public vaci post vent hoy',
#  'tod plataform dic contact wom aca sig contest cer huev exist algui are post vent adem personal ase ir',
#  'abrazam wom contest reclam pesim señal servici intermitent',
#  'hol wom reclam nadi nunc contest import pic jajaj permanent fiest asi hac sent',
#  'jajaj 5 millon client ka atencion via whatsap pal pic wom qued grand ponch',
#  'bitacor capit año 2931 naveg mund desconoc señal callamp wom aun contest',
#  'solicit investig informacion jajaj dej lad zon rural fibr optic jajaj si pag gast dos compañi internet hog movil jajaj wom dos gast total 420',
#  'wom pen aparezc wom teletransport superfici dec servici val hong',
#  'wom jact comun crec much vecs hac cost pesim practic jajaj mam jubil port dic pagari idem 90 entel jajaj met equip mandat a18 mes plan result 20 mil kag mas pas enoj',
#  'hoy internet wom',
#  'wom internet pot',
#  'cambiat wom deci enoj deci',
#  'wom jact comun crec much vecs hac cost pesim practic jajaj mam jubil p',
#  'wom problem cobertur jajaj vari enoj',
#  'wom bac jajaj pas 4g vid señal pesim',
#  'wom fastidi usted envi spam prepag nuev hoy molest',
#  'wom asegur ire wom',
#  'wom usted regul jajaj nob via jajaj verd chist regul dan permis satur red jajaj wom posibl den bw sig vend mentir sumal si cort luz cae wom 0 respald',
#  'tio wom llev mas hor entreg celul acab compr vendedor pued hac aparec stock jajaj aburr quier irme jajaj telefon hic cobr tc jajaj hag ahor suc pedr valdivi',
#  'hol wom reclam nadi nunc contest import pic jajaj permanent fiest',
#  'wom entel cambi wom mierd despu clar tan mierd wom problem cobertur ahor vomist funcion bien mas men',
#  'wom estim tercer seman vam cuart esper equip cer respuest',
#  'wom adem jajaj llev intent mes trat renov iphon regres llam jajaj cost mund pod renov equip jajaj cuant deb segu esper siend client mas tres años',
#  'wom ejecut quis escuch coloc model telefon distint compr',
#  'wom cer respuest',
#  'wom jug empapel chuch das',
#  'wom hol wom aca form club put servici hoy',
#  'wom si jajaj bast eper jajaj hoy dia trabaj jajaj hag jajaj val callamp',
#  'wom movist clar mal jajaj virgin idem ocup movist wom hac dos mes bien jajaj chacre jajaj copi mal mañ jajaj contest twit',
#  'wom quellon chilo jajaj señal 4g filet jajaj hac 6 mes anda horribl hoy pas mal mal',
#  'wom choc ver andan preocup brom public mem respond equip garanti nolecomprenawom',
#  'wom pur popul weon mejor servici cuent',
#  'wom cag bols hac 1 mes aun dan respuest',
#  'wom telefon pierd señal cad rat jajaj reinici cad 10 minut',
#  'wom hac 3 dias señal telefon internet posibl',
#  'wom estan pur wov',
#  'señal wom horribl flor',
#  'sol mal suert pas zon bord wom cad lug visit zon pue jajaj cortenl viend entel',
#  'wom tio wom buen plan jajaj buen promocion señal orto qued aun 16 mes chit pen',
#  'wom pretend mejor red puq trat ver fot jajaj vide carg jajaj apart mas jajaj tambi quer mejor servici',
#  'señor servici dad wom 8 mes solucion jajaj qued constanci',
#  'wom estan ofrec plan portabil jajaj cobertur servici engañ jajaj ahor perdi servici necesit recuper numer',
#  'wom aqui quis pas numer oper dijeron obligatori necesit dni permanent despu 2 años mierd',
#  'wom estim jajaj si pag plan fech vencimient normal jajaj bloqu complet servici pod recib si quier llam abus pod jajaj casi oblig pag',
#  'wom holi jajaj veloc tan mal quier ver netflix carg nunc enoj',
#  'wom lament jajaj compañi inviert santiag zon alej santiag jajaj dem toc ma jajaj tambi llam zon roj jsjsjs mism tambi internet hog pesim encant',
#  'wom desactiv servici hab solicit jajaj esper llam urgent enoj',
#  'wom pas señal va tiemp internet 4g lent enoj cobertur vez aument pesim ultim tiemp val pesim',
#  'wom graci tiempoper señal nul veloc 4gpesim jajaj volvi',
#  'vam wom hor compr servici region nefast',
#  'amig wom mejor señal jajaj favor jajaj lanc jajaj malalhu jajaj melefqu panguipulli sol h cos anda aca',
#  'wom olvidal jan jajaj cambi compañi jajaj trabaj panguipulli jam señal jajaj alla camin jajaj dec iba neltum jajaj pto fuy jajaj liquiñ jajaj etc jajaj cer señal pesim',
#  'wom hac tiemp fall ap desinstal ver si sig igual necesit ver plan jajaj bolet ocup',
#  'wom arregl mierd señal puent alto jajaj lleg 3g',
#  'wom internet mierd cae put rat silv mand wsp men dem arregl cag internet',
#  'entel wom mism jajaj hij da señal chip wom compr escrib part bail ultim aca',
#  'wom contrat hac men seman wom carg casi hac test veloc marc chist necesit solucion supuest 4g',
#  'wom compr chip nuev jajaj chip wom mal calid jajaj cambi cad año año medi suert',
#  'wom oye wom explicam jajaj tan mal señal jajaj cae cad rat mal cobertur si algui mas suced molest cuent dia minim quier servici calid exij tal usted exig',
#  'wom pas tio wom 4g line 1 cad vez peor',
#  'mal servici wom jajaj llam ver problem tecnic equip line 20 minut despu ejecut dig vay sucursal jajaj pregunt solucion problem sencill indic pregunt alla jajaj plop condorit',
#  'mal servici wom jajaj llam ver problem tecnic equip line 20 minut q',
#  'tio wom incomunic jajaj telefon internet onda wom pd aqui pid compart internet pa reclam',
#  'wom nuev llam solicit wom sernac pus reclam molest parec sirv tampoc',
#  'wom hac dos mes veng compr bols internet funcion men pokemon go enoj',
#  'wom ctm pesim señal medi cuid',
#  'increibl jajaj quier cambi equip wom dej dat llam nadi capaz contestart sol dic vay sucursal parec hor irse compañi',
#  'wom asi siempr jajaj esper',
#  'pens habi hech cambi wom mas gig señal hoy esper dos mes pa cambi nuev enoj',
#  'put deb ser miser vid algui cuy unic final esper lleg fin seman',
#  'wom centr concepcion señal poquit mejor hoy',
#  'wom mal servici despu antigu jajaj dan ningun benefici jajaj 7 lin antigu jajaj hor irse',
#  'wom devuelvanm servici mejor jajaj dia señal jajaj solicitud s121424062901',
#  'tio wom cambi mejor celul señal internet pelot jajaj carg suert pud post pen',
#  'wom pas tan chever ahor 4g vuelt mierd 19 mas alla 0 casi impos naveg decent habl si ando san jos maip arregl servici ves gast wn comercial',
#  'wom pur cuent pelot señal pesim',
#  'alcanc usar medi hor red wom dej funcion asi mas jajaj qued bols carg men mal use chip prueb vez port',
#  'llev 8 mes servici pesim wom veloc navegacion bajisim jajaj segun hog zon limit jajaj comun lamp sector residencial limit solucion jajaj qued jajaj zon limit acab jajaj vergüenz',
#  'decepcion wom inscrit unas 5 vec renov equip ofert pagin hac mas seman esper llam necesit urgenci renov equip',
#  'wom usan letr chic tampoc verific ident client sac nombr telefon documentacion fals',
#  ...]
