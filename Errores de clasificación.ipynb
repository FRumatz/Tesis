# %%
#importar librerias 
import numpy as np
import pandas as pd

# %%
#importar data set
data=pd.read_excel('SA.xlsx')

# %%
data = data[['text','sentiment']]

# %%
##Limpieza de texto
import re 
def clean_text (df, text_field): 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'https://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', ' ', elem ))   
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'publici(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'publicidad', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@wom(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'wom', elem ))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'wom(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'wom', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@entel(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+' , 'entel', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'@movistar(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'movistar', elem))
    df [text_field] = df [text_field].str.lower() 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:á)', 'a', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:é)', 'e', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:í)', 'i', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ó)', 'o', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ú)', 'u', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:ll)', 'yxy', elem))#guardar las ll 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:rr)', 'yxr', elem))#guardar las rr 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(.)\1+', r'\1', elem))#saca letras repetidas
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:yxy)', 'll', elem))#devuelve  la ll
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:yxr)', 'rr', elem))#devuelve  la rr
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:bkn)', 'buena', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:rt )', ' ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?: q )', ' que ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?: k )', ' que ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:guena)', ' buena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:wena)', ' buena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:\\n)', ' ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'jajaja(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'jajaja', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'ajaja(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', 'jajaja', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😂,🤣,😅])', ' jajaja ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😁,😎,😊,😘,🙈,🤭,😋,😄,😆,🙌🏻])', ' bien ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😡,😠,😒,🤬])', ' enojo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[😭,😢,😪,😞,😔,😫,😌,😩])', ' pena ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[🍄,🤦,🤦,🤦🏼,🤦,😤,😕,💩,😖,🤮,🐌,🖕,😑,💔,👎🏻])', ' pesimo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[❤️,💓,💕,💜,😍])', ' encanta ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:[👏])', ' bravo ', elem))
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'(?:@[\w_]+)', ' ', elem)) #quita las menciones 
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'[^\w\ \s]','', elem)) #quita los emoticones (Deja solo letras y espacios)
    df [text_field] = df [text_field].apply(lambda elem: re.sub(r'\b(\w+)( \1\b)+', r'\1', elem))#elimina repetidos
    return df 
data=clean_text(data,'text')
data=clean_text(data,'text')
#quitar neutros 
dataset = data[data.sentiment != 'Neutro']

# %%
#quitar stop word y realizar steming
import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud,STOPWORDS
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("spanish")
corpus=[]
for i in range(0,1098):
    text=dataset['text'][i]
    text=text.split()
    text=[stemmer.stem(word) for word in text if not word in set(stopwords.words('spanish'))]
    text=' '.join(text)
    corpus.append(text)

# %%
#crear la bolsa de palabras
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer() 
X = pd.DataFrame(cv.fit_transform(corpus).toarray())
y = pd.Series(dataset.iloc[:,1])

# %%
#SVM LINEALMENTE SEPARABLE
# Dividir el data set en conjunto de entrenamiento y conjunto de prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Ajustar el SVM en el Conjunto de Entrenamiento
from sklearn.svm import SVC
classifier = SVC(kernel = "linear", random_state = 0)
classifier.fit(X_train, y_train)

# Predicción de los resultados con el Conjunto de Prueba
y_pred  = classifier.predict(X_test)

# %%
prueba=pd.merge(y_test, dataset, right_index=True, left_index=True)
df=prueba.reset_index()

# %%
y_pred=pd.DataFrame({'y_pred':y_pred})
dat=df.join(y_pred)

# %%
errores_svmlineal = dat[dat.y_pred != dat.sentiment_y]
errores_svmlineal.to_excel("errores_svmlineal.xls")
errores_svmlineal
# Out:
#      index sentiment_x                                               text  \
# 6      752        Malo  he cometido grandes errores pero el que mas me...
# 14     359        Malo  wom me tuve que cambiar de wom estan guateando...
# 18     240      Bueno   se me perdio el telefono en el taxi y por cosa...
# 21     958        Malo  wom tio wom muy buenos los planes jajaja muy b...
# 27      70      Bueno    wom me porte a wom el fin de semana jajaja hi...
# 28     933        Malo   wom problemas de cobertura jajaja para variar...
# 37     175      Bueno   wom si su diseñador de publicidad fuera presid...
# 62     609        Malo   wom ahi que ser bien para estar tras años y n...
# 65      34      Bueno    wom y que tal wom mi cuñada dice que le anda ...
# 68     655        Malo  wom algun problema\n hay dificultad para el en...
# 71     267      Bueno    wom estoy en el campo y ahora deje solo el 3g...
# 74     316        Malo  wom tendra publicidad muy creativa y todo jaja...
# 78     183      Bueno                            wom son increibles bien
# 82      18      Bueno    cambiate a wom nunca he tenido ningun problem...
# 87     268      Bueno    wom activo el 4g y la antena esta a la chucha...
# 90     231      Bueno    wom me da pena tu problema pero yo uso wom ha...
# 98     465        Malo         yo diria que wom esos vomitables al maximo
# 105    204      Bueno   quiero contar mi experiencia con el servicio d...
# 114    270      Bueno   movistar cueck pesimo bien pesimo bien por eso...
# 122    667        Malo  wom en huawei me dieron un dcto para solicitar...
# 125    526        Malo   wom somo varios los afectados insisten que no...
# 128    865        Malo         wom pf jajaja eso fue ayer pesimo encanta
# 133    202      Bueno   wom tio wom nesesito de su ayuda nesesito ese ...
# 135     45      Bueno    wom incorrecto son 50 gb en 4g mas 30 gb en 3...
# 161    264      Bueno   tio wom nos puede contar de donde son las herm...
# 173    720        Malo  wom tengo problema con el internet toda la mañ...
# 179    903        Malo  wom tanto que hablan sobres sus 5 millones de ...
# 181    247      Bueno   porte mi numero a wom y cero problemas en el m...
# 182    251      Bueno    wom mira asi me andaba movistar jajaja cuando...
# 206    308        Malo    wom gracias ingresare inmediatamente el reclamo
# 209    200      Bueno   tio wom por favor quiero ganar el huawei p30 y...
#
#     sentiment_y  y_pred
# 6          Malo  Bueno
# 14         Malo  Bueno
# 18       Bueno     Malo
# 21         Malo  Bueno
# 27       Bueno     Malo
# 28         Malo  Bueno
# 37       Bueno     Malo
# 62         Malo  Bueno
# 65       Bueno     Malo
# 68         Malo  Bueno
# 71       Bueno     Malo
# 74         Malo  Bueno
# 78       Bueno     Malo
# 82       Bueno     Malo
# 87       Bueno     Malo
# 90       Bueno     Malo
# 98         Malo  Bueno
# 105      Bueno     Malo
# 114      Bueno     Malo
# 122        Malo  Bueno
# 125        Malo  Bueno
# 128        Malo  Bueno
# 133      Bueno     Malo
# 135      Bueno     Malo
# 161      Bueno     Malo
# 173        Malo  Bueno
# 179        Malo  Bueno
# 181      Bueno     Malo
# 182      Bueno     Malo
# 206        Malo  Bueno
# 209      Bueno     Malo

# %%
# Aplicar Validación cruzada
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
accuracies.mean()
# Out:
# 0.8633490073145247

# %%
#SVM aplicando un kernel gaussiano
# Dividir el data set en conjunto de entrenamiento y conjunto de prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Ajustar el clasificador en el Conjunto de Entrenamiento
from sklearn.svm import SVC
classifier = SVC(kernel = "rbf",C=100, gamma='scale', random_state = 0)
classifier.fit(X_train, y_train)

# Predicción de los resultados con el Conjunto de Prueba
y_pred  = classifier.predict(X_test)

# %%
# Aplicar Validación cruzada
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
accuracies.mean()
# Out:
# 0.8792972831765935

# %%
prueba=pd.merge(y_test, dataset, right_index=True, left_index=True)
df=prueba.reset_index()

# %%
y_pred=pd.DataFrame({'y_pred':y_pred})
dat=df.join(y_pred)

# %%
errores_svmgauss = dat[dat.y_pred != dat.sentiment_y]
errores_svmgauss.to_excel("errores_svmlineal.xls")
errores_svmgauss
# Out:
#      index sentiment_x                                               text  \
# 6      752        Malo  he cometido grandes errores pero el que mas me...
# 17      14      Bueno    entel compadre jajaja no pierda mas plata ni ...
# 18     240      Bueno   se me perdio el telefono en el taxi y por cosa...
# 27      70      Bueno    wom me porte a wom el fin de semana jajaja hi...
# 28     933        Malo   wom problemas de cobertura jajaja para variar...
# 32     582        Malo              wom ajaja una parte que funcione bien
# 37     175      Bueno   wom si su diseñador de publicidad fuera presid...
# 46      31      Bueno    amigos de wom ustedes son mi empresa hace mas...
# 60      85      Bueno    wom en movil y en fijo volandole la raja a lo...
# 62     609        Malo   wom ahi que ser bien para estar tras años y n...
# 65      34      Bueno    wom y que tal wom mi cuñada dice que le anda ...
# 71     267      Bueno    wom estoy en el campo y ahora deje solo el 3g...
# 82      18      Bueno    cambiate a wom nunca he tenido ningun problem...
# 87     268      Bueno    wom activo el 4g y la antena esta a la chucha...
# 90     231      Bueno    wom me da pena tu problema pero yo uso wom ha...
# 98     465        Malo         yo diria que wom esos vomitables al maximo
# 105    204      Bueno   quiero contar mi experiencia con el servicio d...
# 114    270      Bueno   movistar cueck pesimo bien pesimo bien por eso...
# 115    103      Bueno                                    wom que estrella
# 117    523        Malo  wom sres jajaja nunca tengo 4g en ninguna part...
# 128    865        Malo         wom pf jajaja eso fue ayer pesimo encanta
# 133    202      Bueno   wom tio wom nesesito de su ayuda nesesito ese ...
# 135     45      Bueno    wom incorrecto son 50 gb en 4g mas 30 gb en 3...
# 161    264      Bueno   tio wom nos puede contar de donde son las herm...
# 171    795        Malo  wom ya arreglamos el problema los salimos de w...
# 179    903        Malo  wom tanto que hablan sobres sus 5 millones de ...
# 181    247      Bueno   porte mi numero a wom y cero problemas en el m...
# 182    251      Bueno    wom mira asi me andaba movistar jajaja cuando...
# 206    308        Malo    wom gracias ingresare inmediatamente el reclamo
# 209    200      Bueno   tio wom por favor quiero ganar el huawei p30 y...
#
#     sentiment_y  y_pred
# 6          Malo  Bueno
# 17       Bueno     Malo
# 18       Bueno     Malo
# 27       Bueno     Malo
# 28         Malo  Bueno
# 32         Malo  Bueno
# 37       Bueno     Malo
# 46       Bueno     Malo
# 60       Bueno     Malo
# 62         Malo  Bueno
# 65       Bueno     Malo
# 71       Bueno     Malo
# 82       Bueno     Malo
# 87       Bueno     Malo
# 90       Bueno     Malo
# 98         Malo  Bueno
# 105      Bueno     Malo
# 114      Bueno     Malo
# 115      Bueno     Malo
# 117        Malo  Bueno
# 128        Malo  Bueno
# 133      Bueno     Malo
# 135      Bueno     Malo
# 161      Bueno     Malo
# 171        Malo  Bueno
# 179        Malo  Bueno
# 181      Bueno     Malo
# 182      Bueno     Malo
# 206        Malo  Bueno
# 209      Bueno     Malo
